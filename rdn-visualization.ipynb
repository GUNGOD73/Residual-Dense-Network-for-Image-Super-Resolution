# %%
import numpy as np
import cv2
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import os
# Out:
# 2024-05-06 09:07:10.401266: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 09:07:10.401402: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 09:07:10.604799: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
img1 = Image.open("/kaggle/input/miniproj/div2k/Validation/LR/lr_images/101.jpg")
img2 = Image.open("/kaggle/input/rdn-on-div2k-padded/Results/4.jpg")
img3 = Image.open("/kaggle/input/miniproj/div2k/Validation/HR/hr_images/101.jpg")

plt.figure(figsize=(40,20))

plt.subplot(1,3,1)
plt.imshow(img1)
plt.title("Low quality image")

plt.subplot(1,3,2)
plt.imshow(img3)
plt.title("Super resolution by RDN")

plt.subplot(1,3,3)
plt.imshow(img3)
plt.title("Actual high quality image")

plt.show()
